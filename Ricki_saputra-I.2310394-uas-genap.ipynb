# %%
# Nama : Ricki Saputra
# NIM. : I.2310394

import kagglehub

# Download latest version
path = kagglehub.dataset_download("muharfanb/data-kecepatan-internet")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /root/.cache/kagglehub/datasets/muharfanb/data-kecepatan-internet/versions/1

# %%
import os

dataset_path = path
files = os.listdir(dataset_path)
print("Nama Files:", files)
# Out:
# Nama Files: ['indonesia-internet-speed.csv']

# %%
import pandas as pd
data_file = os.path.join(dataset_path, 'indonesia-internet-speed.csv')
data = pd.read_csv(data_file)
data
# Out:
#                   kota  mobile  fixed
# 0           Abiansemal     NaN  46.98
# 1             Ambarawa     NaN  14.78
# 2            Baleendah     NaN  21.13
# 3           Balikpapan   35.12  24.06
# 4           Banda Aceh   34.97  26.13
# 5       Bandar Lampung   23.93  20.64
# 6              Bandung   19.91  27.31
# 7          Banguntapan   25.85  19.99
# 8           Banjarbaru   32.34  22.60
# 9          Banjarmasin   25.84  28.56
# 10       Banjarnegara    16.52  12.52
# 11              Bantul   24.22  19.33
# 12               Batam   26.53  23.49
# 13              Batang     NaN  18.99
# 14                Batu     NaN  18.17
# 15           Batujajar     NaN  28.71
# 16              Bekasi   23.86  30.45
# 17            Bengkulu   24.96  18.23
# 18              Bergas     NaN  17.27
# 19              Binjai     NaN  25.91
# 20              Blitar   21.47   9.22
# 21               Blora     NaN  20.94
# 22               Bogor   18.86  27.95
# 23          Bojonegoro     NaN  11.69
# ...

# %%
data.describe()
# Out:
#           mobile       fixed
# count  85.000000  150.000000
# mean   23.386706   23.205533
# std     5.495612    7.344070
# min    12.080000    6.450000
# 25%    19.380000   19.427500
# 50%    22.570000   23.245000
# 75%    26.530000   26.477500
# max    39.050000   49.010000

# %%
data.isna()
# Out:
#       kota  mobile  fixed
# 0    False    True  False
# 1    False    True  False
# 2    False    True  False
# 3    False   False  False
# 4    False   False  False
# 5    False   False  False
# 6    False   False  False
# 7    False   False  False
# 8    False   False  False
# 9    False   False  False
# 10   False   False  False
# 11   False   False  False
# 12   False   False  False
# 13   False    True  False
# 14   False    True  False
# 15   False    True  False
# 16   False   False  False
# 17   False   False  False
# 18   False    True  False
# 19   False    True  False
# 20   False   False  False
# 21   False    True  False
# 22   False   False  False
# 23   False    True  False
# 24   False   False  False
# 25   False    True  False
# 26   False    True  False
# 27   False    True  False
# 28   False    True  False
# 29   False    True  False
# 30   False    True  False
# 31   False   False  False
# 32   False    True  False
# 33   False    True  False
# ...

# %%
data.isna().mean() * 100
# Out:
# kota       0.000000
# mobile    43.333333
# fixed      0.000000
# dtype: float64

# %%
data.columns
# Out:
# Index(['kota', 'mobile', 'fixed'], dtype='object')

# %%
data.describe()
# Out:
#           mobile       fixed
# count  85.000000  150.000000
# mean   23.386706   23.205533
# std     5.495612    7.344070
# min    12.080000    6.450000
# 25%    19.380000   19.427500
# 50%    22.570000   23.245000
# 75%    26.530000   26.477500
# max    39.050000   49.010000

# %% [markdown]
# ### dari data di atas Variasi antara kota cukup besar, baik untuk mobile maupun fixed. Beberapa kota masih memiliki penggunaan telepon tetap yang rendah seperti 6.45, sementara yang lain tinggi yaitu 49.0, menunjukkan ketimpangan dari layanan telepon.

# %%
data.isnull().sum()
# Out:
# kota       0
# mobile    65
# fixed      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le_kota = LabelEncoder()
data['kota_encoded'] = le_kota.fit_transform(data['kota'])

# %%
data.columns
# Out:
# Index(['kota', 'mobile', 'fixed', 'kota_encoded'], dtype='object')

# %%
X = data[['mobile', 'fixed']]
y = data['kota_encoded']

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data
# Out:
#                   kota  mobile  fixed  kota_encoded
# 0           Abiansemal     NaN  46.98             0
# 1             Ambarawa     NaN  14.78             1
# 2            Baleendah     NaN  21.13             2
# 3           Balikpapan   35.12  24.06             3
# 4           Banda Aceh   34.97  26.13             4
# 5       Bandar Lampung   23.93  20.64             5
# 6              Bandung   19.91  27.31             6
# 7          Banguntapan   25.85  19.99             7
# 8           Banjarbaru   32.34  22.60             8
# 9          Banjarmasin   25.84  28.56             9
# 10       Banjarnegara    16.52  12.52            10
# 11              Bantul   24.22  19.33            11
# 12               Batam   26.53  23.49            12
# 13              Batang     NaN  18.99            13
# 14                Batu     NaN  18.17            14
# 15           Batujajar     NaN  28.71            15
# 16              Bekasi   23.86  30.45            16
# ...

# %%
X_impute = X.fillna(X.mean())
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_impute)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

X = data[['mobile', 'fixed']].fillna(data[['mobile', 'fixed']].mean())  # pastikan tidak ada NaN

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c='blue', edgecolor='k', marker='o')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Visualisasi(PCA 2D)")
plt.show()

# %% [markdown]
# ##ensemble learning
# ###baging

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

X = data[['mobile', 'fixed']]
y = data['kota_encoded']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=0)

rf = RandomForestRegressor(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)

y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)

print("Random Forest - MSE Train:", mean_squared_error(y_train, y_pred_train))
print("Random Forest - MSE Test:", mean_squared_error(y_test, y_pred_test))
# Out:
# Random Forest - MSE Train: 396.62610286368846
# Random Forest - MSE Test: 1760.119104821803

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.bar(le_kota.classes_, np.bincount(y_encoded))
plt.xticks(rotation=90)
plt.xlabel("Kota")
plt.ylabel("Jumlah Data")
plt.title("Distribusi Data per Kota")
plt.show()

# %% [markdown]
# ### adabost regresor

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer

X = data[['mobile', 'fixed']]
y = data['kota_encoded']

X_train, X_test, y_train, y_test = train_test_split(X_filled, y, test_size=0.35, random_state=0)

Test:", accuracy_score(y_test, y_pred_test_gb))
# Out:
#   File "/tmp/ipython-input-1878530461.py", line 11
#     Test:", accuracy_score(y_test, y_pred_test_gb))
#          ^
# SyntaxError: unterminated string literal (detected at line 11)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
y_pred_train_rf = rf.predict(X_train)
y_pred_test_rf = rf.predict(X_test)
print("RandomForest - Akurasi Train:", accuracy_score(y_train, y_pred_train_rf))
print("RandomForest - Akurasi Test:", accuracy_score(y_test, y_pred_test_rf))
# Out:
# RandomForest - Akurasi Train: 1.0
# RandomForest - Akurasi Test: 0.0

# %%
# AdaBoost
ada = AdaBoostClassifier(n_estimators=100, random_state=0)
ada.fit(X_train, y_train)
y_pred_train_ada = ada.predict(X_train)
y_pred_test_ada = ada.predict(X_test)
print("AdaBoost - Akurasi Train:", accuracy_score(y_train, y_pred_train_ada))
print("AdaBoost - Akurasi Test:", accuracy_score(y_test, y_pred_test_ada))
# Out:
# AdaBoost - Akurasi Train: 0.09278350515463918
# AdaBoost - Akurasi Test: 0.0

# %%
# GradientBoosting
gb = GradientBoostingClassifier(n_estimators=100, random_state=0)
gb.fit(X_train, y_train)
y_pred_train_gb = gb.predict(X_train)
y_pred_test_gb = gb.predict(X_test)
print("GradientBoosting - Akurasi Train:", accuracy_score(y_train, y_pred_train_gb))
print("GradientBoosting - Akurasi Test:", accuracy_score(y_test, y_pred_test_gb))
# Out:
# GradientBoosting - Akurasi Train: 1.0
# GradientBoosting - Akurasi Test: 0.0
